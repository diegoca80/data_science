# %%
import numpy as np
import pandas as pd # Pandas is an easy-to-use data structures and data analysis tools
import matplotlib.pyplot as plt # Matplot is a common Python lib for plotting
# %matplotlib inline
import seaborn as sns # Seaborn is a great tool for data analysis graphs
from scipy import stats # Useful for correlation

# %% [markdown]
# Read the entire dataset provided using pandas

# %%
df = pd.read_csv("datatraining.csv")

# %% [markdown]
# Use of head() function to provide the first 5 lines of the dataset

# %%
df.head()
# Out:
#    id                 date  Temperature  Humidity  Light     CO2  \
# 0   1  2015-02-04 17:51:00        23.18   27.2720  426.0  721.25
# 1   2  2015-02-04 17:51:59        23.15   27.2675  429.5  714.00
# 2   3  2015-02-04 17:53:00        23.15   27.2450  426.0  713.50
# 3   4  2015-02-04 17:54:00        23.15   27.2000  426.0  708.25
# 4   5  2015-02-04 17:55:00        23.10   27.2000  426.0  704.50
#
#    HumidityRatio  Occupancy
# 0       0.004793          1
# 1       0.004783          1
# 2       0.004779          1
# 3       0.004772          1
# 4       0.004757          1

# %% [markdown]
# Let's now analyze the relationship between occupancy and the continous variables.
#
# We can use a point-biserial correlation coefficient to highlight the relationship between discrete variables and continous variables. If r is greater than about 0.3 this indicates good correlation and between 0.1 and 0.3 indicates a medium correlation.
# To determine whether the correlation between variables is significant, compare the p-value to the significance level(~0.05). If p < significance level so the correlation indicates linear relationship.

# %%
# %%javascript
# IPython.OutputArea.auto_scroll_threshold = 9999;
# //A simple command to increase the maximum size of the output cells in the notebook

# %%
fig, axarr = plt.subplots(5, figsize=(12,40))
sns.boxplot(y = 'Occupancy', x = 'Temperature', data = df,width = 0.8,orient = 'h', showmeans = True, fliersize = 3, ax = axarr[0])
# Calculate the correlation coefficient
r, p = stats.pointbiserialr(df['Occupancy'], df['Temperature'])
print ('point biserial correlation r between Occupancy and Temperature is %s with p = %s' %(r,p))
sns.boxplot(y = 'Occupancy', x = 'Humidity', data = df,width = 0.8,orient = 'h', showmeans = True, fliersize = 3, ax = axarr[1])
# Calculate the correlation coefficient
r, p = stats.pointbiserialr(df['Occupancy'], df['Humidity'])
print ('point biserial correlation r between Occupancy and Humidity is %s with p = %s' %(r,p))
sns.boxplot(y = 'Occupancy', x = 'Light', data = df,width = 0.8,orient = 'h', showmeans = True, fliersize = 3, ax = axarr[2])
# Calculate the correlation coefficient
r, p = stats.pointbiserialr(df['Occupancy'], df['Light'])
print ('point biserial correlation r between Occupancy and Light is %s with p = %s' %(r,p))
sns.boxplot(y = 'Occupancy', x = 'CO2', data = df,width = 0.8,orient = 'h', showmeans = True, fliersize = 3, ax = axarr[3])
# Calculate the correlation coefficient
r, p = stats.pointbiserialr(df['Occupancy'], df['CO2'])
print ('point biserial correlation r between Occupancy and CO2 is %s with p = %s' %(r,p))
sns.boxplot(y = 'Occupancy', x = 'HumidityRatio', data = df,width = 0.8,orient = 'h', showmeans = True, fliersize = 3, ax = axarr[4])
# Calculate the correlation coefficient
r, p = stats.pointbiserialr(df['Occupancy'], df['HumidityRatio'])
print ('point biserial correlation r between Occupancy and HumidityRatio is %s with p = %s' %(r,p))
plt.show()
# Out:
# point biserial correlation r between Occupancy and Temperature is 0.538219693018 with p = 0.0
# point biserial correlation r between Occupancy and Humidity is 0.132964241777 with p = 1.93480878174e-33
# point biserial correlation r between Occupancy and Light is 0.907352114996 with p = 0.0
# point biserial correlation r between Occupancy and CO2 is 0.712235235717 with p = 0.0
